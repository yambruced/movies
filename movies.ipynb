# %%
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
m = pd.read_csv("movie.csv")

# %%
m.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
m.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
m.set_index("movie_title",inplace=True)

# %%
m.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
m.sort_values('budget',ascending=False).head(5)
# Out:
#                    color    director_name  num_critic_for_reviews  duration  \
# movie_title
# Lady Vengeance     Color   Chan-wook Park                   202.0     112.0
# Fateless           Color     Lajos Koltai                    73.0     134.0
# Princess Mononoke  Color   Hayao Miyazaki                   174.0     134.0
# Steamboy           Color  Katsuhiro Ôtomo                   105.0     103.0
# Akira              Color  Katsuhiro Ôtomo                   150.0     124.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Lady Vengeance                         0.0                    38.0
# Fateless                              45.0                     0.0
# Princess Mononoke                   6000.0                   745.0
# Steamboy                              78.0                   101.0
# Akira                                 78.0                     4.0
#
#                          actor_2_name  actor_1_facebook_likes      gross  \
# ...

# %%
m.sort_values('gross',ascending=False).head(5)
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# movie_title
# Avatar           Color      James Cameron                   723.0     178.0
# Titanic          Color      James Cameron                   315.0     194.0
# Jurassic World   Color    Colin Trevorrow                   644.0     124.0
# The Avengers     Color        Joss Whedon                   703.0     173.0
# The Dark Knight  Color  Christopher Nolan                   645.0     152.0
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Avatar                               0.0                   855.0
# Titanic                              0.0                   794.0
# Jurassic World                     365.0                  1000.0
# The Avengers                         0.0                 19000.0
# The Dark Knight                  22000.0                 11000.0
#
#                       actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# ...

# %%
m[m['content_rating'] == 'PG-13'].sort_values('budget',ascending=False).head(5)
# Out:
#                                           color    director_name  \
# movie_title
# Princess Mononoke                         Color   Hayao Miyazaki
# Steamboy                                  Color  Katsuhiro Ôtomo
# Tango                                     Color     Carlos Saura
# Pirates of the Caribbean: At World's End  Color   Gore Verbinski
# John Carter                               Color   Andrew Stanton
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Princess Mononoke                                          174.0     134.0
# Steamboy                                                   105.0     103.0
# Tango                                                       35.0     115.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# John Carter                                                462.0     132.0
#
#                                           director_facebook_likes  \
# movie_title
# ...

# %%
m[m['content_rating'] == 'PG-13'].sort_values('gross',ascending=False).head(5)
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# movie_title
# Avatar           Color      James Cameron                   723.0     178.0
# Titanic          Color      James Cameron                   315.0     194.0
# Jurassic World   Color    Colin Trevorrow                   644.0     124.0
# The Avengers     Color        Joss Whedon                   703.0     173.0
# The Dark Knight  Color  Christopher Nolan                   645.0     152.0
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Avatar                               0.0                   855.0
# Titanic                              0.0                   794.0
# Jurassic World                     365.0                  1000.0
# The Avengers                         0.0                 19000.0
# The Dark Knight                  22000.0                 11000.0
#
#                       actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# ...

# %%
m[m['content_rating'] == 'PG-13'].sort_values('budget',ascending=False).tail(5)
# Out:
#                               color  director_name  num_critic_for_reviews  \
# movie_title
# Dogtown and Z-Boys  Black and White  Stacy Peralta                    86.0
# Shotgun Stories               Color   Jeff Nichols                    85.0
# Heroes of Dirt                Color    Eric Bugbee                     2.0
# The Mighty                    Color  Peter Chelsom                    57.0
# Shanghai Calling              Color    Daniel Hsia                    14.0
#
#                     duration  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Dogtown and Z-Boys      91.0                    147.0                     5.0
# Shotgun Stories         92.0                    337.0                    22.0
# Heroes of Dirt          98.0                      0.0                    21.0
# The Mighty             100.0                     23.0                   545.0
# Shanghai Calling       100.0                      0.0                   489.0
#
# ...

# %%
m[m['content_rating'] == 'PG-13'].sort_values('gross',ascending=False).tail(5)
# Out:
#                   color    director_name  num_critic_for_reviews  duration  \
# movie_title
# Super Hybrid      Color     Eric Valette                    42.0      94.0
# Heroes of Dirt    Color      Eric Bugbee                     2.0      98.0
# Romantic Schemer  Color        Valentine                     NaN       NaN
# The Signal        Color   William Eubank                   161.0      97.0
# The Mongol King   Color  Anthony Vallone                     NaN      84.0
#
#                   director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Super Hybrid                          2.0                   156.0
# Heroes of Dirt                        0.0                    21.0
# Romantic Schemer                      0.0                     NaN
# The Signal                           18.0                   236.0
# The Mongol King                       2.0                     2.0
#
#                     actor_2_name  actor_1_facebook_likes  gross  \
# movie_title
# ...

# %%
m[m['content_rating'] == 'R'].sort_values('budget',ascending=False).head(5)
# Out:
#                         color    director_name  num_critic_for_reviews  \
# movie_title
# Lady Vengeance          Color   Chan-wook Park                   202.0
# Fateless                Color     Lajos Koltai                    73.0
# Akira                   Color  Katsuhiro Ôtomo                   150.0
# Kabhi Alvida Naa Kehna  Color      Karan Johar                    20.0
# Red Cliff               Color         John Woo                   160.0
#
#                         duration  director_facebook_likes  \
# movie_title
# Lady Vengeance             112.0                      0.0
# Fateless                   134.0                     45.0
# Akira                      124.0                     78.0
# Kabhi Alvida Naa Kehna     193.0                    160.0
# Red Cliff                  150.0                    610.0
#
#                         actor_3_facebook_likes         actor_2_name  \
# movie_title
# Lady Vengeance                            38.0         Yeong-ae Lee
# ...

# %%
m[m['content_rating'] == 'R'].sort_values('gross',ascending=False).head(5)
# Out:
#                       color   director_name  num_critic_for_reviews  duration  \
# movie_title
# Deadpool              Color      Tim Miller                   579.0     108.0
# American Sniper       Color  Clint Eastwood                   490.0     133.0
# The Matrix Reloaded   Color  Lana Wachowski                   275.0     138.0
# The Hangover          Color   Todd Phillips                   334.0     108.0
# The Hangover Part II  Color   Todd Phillips                   383.0     102.0
#
#                       director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Deadpool                                 84.0                   361.0
# American Sniper                       16000.0                   318.0
# The Matrix Reloaded                       0.0                    30.0
# The Hangover                            480.0                   706.0
# The Hangover Part II                    480.0                   461.0
#
# ...

# %%
m[m['content_rating'] == 'R'].sort_values('budget',ascending=False).tail(5)
# Out:
#                                color    director_name  num_critic_for_reviews  \
# movie_title
# Gabriela                       Color    Bruno Barreto                     1.0
# Mutual Appreciation  Black and White  Andrew Bujalski                    52.0
# Down Terrace                   Color     Ben Wheatley                    53.0
# Rampage                        Color         Uwe Boll                    58.0
# Exeter                         Color    Marcus Nispel                    43.0
#
#                      duration  director_facebook_likes  \
# movie_title
# Gabriela                 99.0                      9.0
# Mutual Appreciation     109.0                     26.0
# Down Terrace             93.0                    214.0
# Rampage                  80.0                    892.0
# Exeter                   91.0                    158.0
#
#                      actor_3_facebook_likes        actor_2_name  \
# movie_title
# ...

# %%
m[m['content_rating'] == 'R'].sort_values('gross',ascending=False).tail(5)
# Out:
#                                  color    director_name  \
# movie_title
# Gabriela                         Color    Bruno Barreto
# This Is Martin Bonner            Color    Chad Hartigan
# Mutual Appreciation    Black and White  Andrew Bujalski
# Rampage                          Color         Uwe Boll
# Exeter                           Color    Marcus Nispel
#
#                        num_critic_for_reviews  duration  \
# movie_title
# Gabriela                                  1.0      99.0
# This Is Martin Bonner                    34.0      83.0
# Mutual Appreciation                      52.0     109.0
# Rampage                                  58.0      80.0
# Exeter                                   43.0      91.0
#
#                        director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Gabriela                                   9.0                     3.0
# This Is Martin Bonner                      3.0                    69.0
# ...

# %%
m[m['genres'] == 'Action|Adventure|Sci-Fi'].sort_values('gross',ascending=False).head(5)
# Out:
#                                      color  director_name  \
# movie_title
# The Avengers                         Color    Joss Whedon
# Avengers: Age of Ultron              Color    Joss Whedon
# Iron Man 3                           Color    Shane Black
# Captain America: Civil War           Color  Anthony Russo
# Transformers: Revenge of the Fallen  Color    Michael Bay
#
#                                      num_critic_for_reviews  duration  \
# movie_title
# The Avengers                                          703.0     173.0
# Avengers: Age of Ultron                               635.0     141.0
# Iron Man 3                                            608.0     195.0
# Captain America: Civil War                            516.0     147.0
# Transformers: Revenge of the Fallen                   366.0     150.0
#
#                                      director_facebook_likes  \
# movie_title
# The Avengers                                             0.0
# ...

# %%
m[m['genres'] == 'Action|Adventure|Sci-Fi'].sort_values('budget',ascending=False).head(5)
# Out:
#                                     color   director_name  \
# movie_title
# John Carter                         Color  Andrew Stanton
# Batman v Superman: Dawn of Justice  Color     Zack Snyder
# Captain America: Civil War          Color   Anthony Russo
# Avengers: Age of Ultron             Color     Joss Whedon
# The Avengers                        Color     Joss Whedon
#
#                                     num_critic_for_reviews  duration  \
# movie_title
# John Carter                                          462.0     132.0
# Batman v Superman: Dawn of Justice                   673.0     183.0
# Captain America: Civil War                           516.0     147.0
# Avengers: Age of Ultron                              635.0     141.0
# The Avengers                                         703.0     173.0
#
#                                     director_facebook_likes  \
# movie_title
# John Carter                                           475.0
# ...

# %%
m[m['country'] == 'USA'].sort_values('gross',ascending=False).head(5)
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# movie_title
# Avatar           Color      James Cameron                   723.0     178.0
# Titanic          Color      James Cameron                   315.0     194.0
# Jurassic World   Color    Colin Trevorrow                   644.0     124.0
# The Avengers     Color        Joss Whedon                   703.0     173.0
# The Dark Knight  Color  Christopher Nolan                   645.0     152.0
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Avatar                               0.0                   855.0
# Titanic                              0.0                   794.0
# Jurassic World                     365.0                  1000.0
# The Avengers                         0.0                 19000.0
# The Dark Knight                  22000.0                 11000.0
#
#                       actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# ...

# %%
m[m['country'] == 'USA'].sort_values('budget',ascending=False).head(5)
# Out:
#                                              color   director_name  \
# movie_title
# Pirates of the Caribbean: At World's End     Color  Gore Verbinski
# John Carter                                  Color  Andrew Stanton
# Tangled                                      Color    Nathan Greno
# Spider-Man 3                                 Color       Sam Raimi
# Pirates of the Caribbean: On Stranger Tides  Color    Rob Marshall
#
#                                              num_critic_for_reviews  duration  \
# movie_title
# Pirates of the Caribbean: At World's End                      302.0     169.0
# John Carter                                                   462.0     132.0
# Tangled                                                       324.0     100.0
# Spider-Man 3                                                  392.0     156.0
# Pirates of the Caribbean: On Stranger Tides                   448.0     136.0
#
# ...

# %%
m[m['country'] == 'USA'].sort_values('gross',ascending=False).tail(5)
# Out:
#                               color       director_name  \
# movie_title
# Sanctuary; Quite a Conundrum  Color  Thomas L. Phillips
# Bang                          Color     Ash Baron-Cohen
# The Mongol King               Color     Anthony Vallone
# The Following                 Color                 NaN
# A Plague So Pleasant          Color    Benjamin Roberds
#
#                               num_critic_for_reviews  duration  \
# movie_title
# Sanctuary; Quite a Conundrum                    13.0      82.0
# Bang                                            10.0      98.0
# The Mongol King                                  NaN      84.0
# The Following                                   43.0      43.0
# A Plague So Pleasant                            13.0      76.0
#
#                               director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Sanctuary; Quite a Conundrum                    120.0                    84.0
# ...

# %%
m[m['country'] == 'USA'].sort_values('budget',ascending=False).tail(5)
# Out:
#                   color    director_name  num_critic_for_reviews  duration  \
# movie_title
# Exeter            Color    Marcus Nispel                    43.0      91.0
# On the Downlow    Color     Tadeo Garcia                     NaN      84.0
# Bang              Color  Ash Baron-Cohen                    10.0      98.0
# The Following     Color              NaN                    43.0      43.0
# Shanghai Calling  Color      Daniel Hsia                    14.0     100.0
#
#                   director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Exeter                              158.0                   265.0
# On the Downlow                        5.0                    12.0
# Bang                                  3.0                   152.0
# The Following                         NaN                   319.0
# Shanghai Calling                      0.0                   489.0
#
#                        actor_2_name  actor_1_facebook_likes    gross  \
# movie_title
# ...

# %%
m[m['country'] == 'China'].sort_values('gross',ascending=False).head(5)
# Out:
#                                     color          director_name  \
# movie_title
# Mission: Impossible - Rogue Nation  Color  Christopher McQuarrie
# The Last Emperor                    Color    Bernardo Bertolucci
# House of Flying Daggers             Color            Yimou Zhang
# The Painted Veil                    Color            John Curran
# Curse of the Golden Flower          Color            Yimou Zhang
#
#                                     num_critic_for_reviews  duration  \
# movie_title
# Mission: Impossible - Rogue Nation                   465.0     131.0
# The Last Emperor                                      75.0     219.0
# House of Flying Daggers                              248.0     119.0
# The Painted Veil                                     143.0     125.0
# Curse of the Golden Flower                           189.0     114.0
#
#                                     director_facebook_likes  \
# movie_title
# ...

# %%
m[m['country'] == 'China'].sort_values('budget',ascending=False).head()
# Out:
#                                              color          director_name  \
# movie_title
# Red Cliff                                    Color               John Woo
# Mission: Impossible - Rogue Nation           Color  Christopher McQuarrie
# House of Flying Daggers                      Color            Yimou Zhang
# The Flowers of War                           Color            Yimou Zhang
# Xi you ji zhi: Sun Wukong san da Baigu Jing  Color         Pou-Soi Cheang
#
#                                              num_critic_for_reviews  duration  \
# movie_title
# Red Cliff                                                     160.0     150.0
# Mission: Impossible - Rogue Nation                            465.0     131.0
# House of Flying Daggers                                       248.0     119.0
# The Flowers of War                                            136.0     146.0
# Xi you ji zhi: Sun Wukong san da Baigu Jing                    14.0     119.0
#
# ...

# %%
m[m['country'] == 'China'].sort_values('gross',ascending=False).tail()
# Out:
#                           color director_name  num_critic_for_reviews  \
# movie_title
# Reign of Assassins        Color   Chao-Bin Su                    50.0
# Legend of Kung Fu Rabbit  Color     Lijun Sun                     5.0
# A Tale of Three Cities    Color  Mabel Cheung                     6.0
# Silver Medallist          Color      Hao Ning                     5.0
# Crazy Stone               Color      Hao Ning                    11.0
#
#                           duration  director_facebook_likes  \
# movie_title
# Reign of Assassins           117.0                      2.0
# Legend of Kung Fu Rabbit      89.0                      0.0
# A Tale of Three Cities       130.0                      3.0
# Silver Medallist              99.0                      0.0
# Crazy Stone                   98.0                      0.0
#
#                           actor_3_facebook_likes   actor_2_name  \
# movie_title
# Reign of Assassins                          21.0      Shawn Yue
# ...

# %%
m[m['country'] == 'China'].sort_values('budget',ascending=False).tail()
# Out:
#                                   color  director_name  \
# movie_title
# Out of Inferno                    Color     Danny Pang
# A Woman, a Gun and a Noodle Shop  Color    Yimou Zhang
# Legend of Kung Fu Rabbit          Color      Lijun Sun
# My Lucky Star                     Color  Dennie Gordon
# Coming Home                       Color    Yimou Zhang
#
#                                   num_critic_for_reviews  duration  \
# movie_title
# Out of Inferno                                      23.0     107.0
# A Woman, a Gun and a Noodle Shop                   101.0      95.0
# Legend of Kung Fu Rabbit                             5.0      89.0
# My Lucky Star                                       11.0     114.0
# Coming Home                                         85.0     109.0
#
#                                   director_facebook_likes  \
# movie_title
# Out of Inferno                                       15.0
# A Woman, a Gun and a Noodle Shop                    611.0
# ...

# %%
m[m['director_name'] == 'James Cameron'].sort_values('gross',ascending=False).head()
# Out:
#                             color  director_name  num_critic_for_reviews  \
# movie_title
# Avatar                      Color  James Cameron                   723.0
# Titanic                     Color  James Cameron                   315.0
# Terminator 2: Judgment Day  Color  James Cameron                   210.0
# True Lies                   Color  James Cameron                    94.0
# Aliens                      Color  James Cameron                   250.0
#
#                             duration  director_facebook_likes  \
# movie_title
# Avatar                         178.0                      0.0
# Titanic                        194.0                      0.0
# Terminator 2: Judgment Day     153.0                      0.0
# True Lies                      141.0                      0.0
# Aliens                         154.0                      0.0
#
#                             actor_3_facebook_likes       actor_2_name  \
# movie_title
# ...

# %%
m[m['director_name'] == 'James Cameron'].sort_values('budget',ascending=False).head()
# Out:
#                             color  director_name  num_critic_for_reviews  \
# movie_title
# Avatar                      Color  James Cameron                   723.0
# Titanic                     Color  James Cameron                   315.0
# True Lies                   Color  James Cameron                    94.0
# Terminator 2: Judgment Day  Color  James Cameron                   210.0
# The Abyss                   Color  James Cameron                    82.0
#
#                             duration  director_facebook_likes  \
# movie_title
# Avatar                         178.0                      0.0
# Titanic                        194.0                      0.0
# True Lies                      141.0                      0.0
# Terminator 2: Judgment Day     153.0                      0.0
# The Abyss                      171.0                      0.0
#
#                             actor_3_facebook_likes       actor_2_name  \
# movie_title
# ...

# %%
m[m['director_name'] == 'Christopher Nolan'].sort_values('budget',ascending=False).head(5)
# Out:
#                        color      director_name  num_critic_for_reviews  \
# movie_title
# The Dark Knight Rises  Color  Christopher Nolan                   813.0
# The Dark Knight        Color  Christopher Nolan                   645.0
# Interstellar           Color  Christopher Nolan                   712.0
# Inception              Color  Christopher Nolan                   642.0
# Batman Begins          Color  Christopher Nolan                   478.0
#
#                        duration  director_facebook_likes  \
# movie_title
# The Dark Knight Rises     164.0                  22000.0
# The Dark Knight           152.0                  22000.0
# Interstellar              169.0                  22000.0
# Inception                 148.0                  22000.0
# Batman Begins             128.0                  22000.0
#
#                        actor_3_facebook_likes    actor_2_name  \
# movie_title
# The Dark Knight Rises                 23000.0  Christian Bale
# ...

# %%
m[m['director_name'] == 'Christopher Nolan'].sort_values('gross',ascending=False).head(5)
# Out:
#                        color      director_name  num_critic_for_reviews  \
# movie_title
# The Dark Knight        Color  Christopher Nolan                   645.0
# The Dark Knight Rises  Color  Christopher Nolan                   813.0
# Inception              Color  Christopher Nolan                   642.0
# Batman Begins          Color  Christopher Nolan                   478.0
# Interstellar           Color  Christopher Nolan                   712.0
#
#                        duration  director_facebook_likes  \
# movie_title
# The Dark Knight           152.0                  22000.0
# The Dark Knight Rises     164.0                  22000.0
# Inception                 148.0                  22000.0
# Batman Begins             128.0                  22000.0
# Interstellar              169.0                  22000.0
#
#                        actor_3_facebook_likes    actor_2_name  \
# movie_title
# The Dark Knight                       11000.0    Heath Ledger
# ...

# %%
m[m['actor_1_name'] == 'Robert Downey Jr.'].sort_values('budget',ascending=False).head(5)
# Out:
#                                     color  director_name  \
# movie_title
# Captain America: Civil War          Color  Anthony Russo
# Iron Man 3                          Color    Shane Black
# Iron Man 2                          Color    Jon Favreau
# Iron Man                            Color    Jon Favreau
# Sherlock Holmes: A Game of Shadows  Color    Guy Ritchie
#
#                                     num_critic_for_reviews  duration  \
# movie_title
# Captain America: Civil War                           516.0     147.0
# Iron Man 3                                           608.0     195.0
# Iron Man 2                                           453.0     124.0
# Iron Man                                             486.0     126.0
# Sherlock Holmes: A Game of Shadows                   382.0     129.0
#
#                                     director_facebook_likes  \
# movie_title
# Captain America: Civil War                             94.0
# ...

# %%
m[m['actor_1_name'] == 'Robert Downey Jr.'].sort_values('gross',ascending=False).head(5)
# Out:
#                             color  director_name  num_critic_for_reviews  \
# movie_title
# Iron Man 3                  Color    Shane Black                   608.0
# Captain America: Civil War  Color  Anthony Russo                   516.0
# Iron Man                    Color    Jon Favreau                   486.0
# Iron Man 2                  Color    Jon Favreau                   453.0
# Sherlock Holmes             Color    Guy Ritchie                   415.0
#
#                             duration  director_facebook_likes  \
# movie_title
# Iron Man 3                     195.0                   1000.0
# Captain America: Civil War     147.0                     94.0
# Iron Man                       126.0                   4000.0
# Iron Man 2                     124.0                   4000.0
# Sherlock Holmes                128.0                      0.0
#
#                             actor_3_facebook_likes        actor_2_name  \
# movie_title
# ...

# %%
m.groupby('genres')['gross'].mean().tail()
# Out:
# genres
# Sci-Fi|Thriller     2.979379e+07
# Thriller            5.409697e+05
# Thriller|War                 NaN
# Thriller|Western             NaN
# Western             1.199322e+07
# Name: gross, dtype: float64

# %%
m.groupby('genres')['budget'].mean().tail()
# Out:
# genres
# Sci-Fi|Thriller     2.046200e+07
# Thriller            2.850500e+06
# Thriller|War        6.700000e+06
# Thriller|Western    7.500000e+05
# Western             3.203182e+06
# Name: budget, dtype: float64

# %%
m.groupby('genres')['budget'].mean().head(10)
# Out:
# genres
# Action                                                             5.905000e+07
# Action|Adventure                                                   5.998000e+07
# Action|Adventure|Animation|Comedy|Crime|Family|Fantasy             7.000000e+07
# Action|Adventure|Animation|Comedy|Drama|Family|Fantasy|Thriller    7.000000e+06
# Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi              1.175000e+08
# Action|Adventure|Animation|Comedy|Family                           1.330000e+08
# Action|Adventure|Animation|Comedy|Family|Fantasy                   1.037500e+08
# Action|Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi            9.200000e+07
# Action|Adventure|Animation|Comedy|Family|Sci-Fi                    1.183333e+08
# Action|Adventure|Animation|Comedy|Fantasy                          2.800000e+07
# Name: budget, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.title('Top 10 Movie generes Average Budget')
plt.xlabel('Budget(1e9) in dollars')
m.groupby('genres')['budget'].mean().sort_values(ascending=False).head(10).plot.barh(alpha=.7)

# %%
m.groupby('genres')['gross'].mean().head(10)
# Out:
# genres
# Action                                                             5.952091e+07
# Action|Adventure                                                   1.307968e+08
# Action|Adventure|Animation|Comedy|Crime|Family|Fantasy             1.359691e+07
# Action|Adventure|Animation|Comedy|Drama|Family|Fantasy|Thriller             NaN
# Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi              1.228235e+08
# Action|Adventure|Animation|Comedy|Family                           1.801411e+08
# Action|Adventure|Animation|Comedy|Family|Fantasy                   1.948295e+08
# Action|Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi            8.677642e+07
# Action|Adventure|Animation|Comedy|Family|Sci-Fi                    1.002108e+08
# Action|Adventure|Animation|Comedy|Fantasy                          6.692760e+05
# Name: gross, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.title('Top 10 Movie Genres Average Gross')
plt.xlabel('Budget(1e9) in dollars')
m.groupby('genres')['gross'].mean().sort_values(ascending=False).head(10).plot.barh(alpha=.7)

# %%
m.groupby('genres')['budget'].mean().head(5)
# Out:
# genres
# Action                                                              59050000.0
# Action|Adventure                                                    59980000.0
# Action|Adventure|Animation|Comedy|Crime|Family|Fantasy              70000000.0
# Action|Adventure|Animation|Comedy|Drama|Family|Fantasy|Thriller      7000000.0
# Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi              117500000.0
# Name: budget, dtype: float64

# %%
m.groupby('genres')['duration'].mean().head(5)
# Out:
# genres
# Action                                                             106.181818
# Action|Adventure                                                   113.800000
# Action|Adventure|Animation|Comedy|Crime|Family|Fantasy              95.000000
# Action|Adventure|Animation|Comedy|Drama|Family|Fantasy|Thriller     45.000000
# Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi               96.000000
# Name: duration, dtype: float64

# %%
m.groupby('director_name')['gross'].mean().head(5)
# Out:
# director_name
# A. Raven Cruz             NaN
# Aaron Hann                NaN
# Aaron Schneider     9176553.0
# Aaron Seltzer      48546578.0
# Abel Ferrara        1227324.0
# Name: gross, dtype: float64

# %%
m.groupby('director_name')['budget'].mean().head(5)
# Out:
# director_name
# A. Raven Cruz       1000000.0
# Aaron Hann                NaN
# Aaron Schneider     7500000.0
# Aaron Seltzer      20000000.0
# Abel Ferrara       12500000.0
# Name: budget, dtype: float64

# %%
m.groupby('director_name')['gross'].mean().tail(5)
# Out:
# director_name
# Zoran Lisinac               NaN
# Álex de la Iglesia       3607.0
# Émile Gaudreault      6239558.0
# Éric Tessier                NaN
# Étienne Faure               NaN
# Name: gross, dtype: float64

# %%
m.groupby('director_name')['budget'].mean().tail(5)
# Out:
# director_name
# Zoran Lisinac           250000.0
# Álex de la Iglesia    10000000.0
# Émile Gaudreault       5000000.0
# Éric Tessier           3200000.0
# Étienne Faure           500000.0
# Name: budget, dtype: float64

# %%
m.groupby('actor_1_name')['gross'].mean().head(5)
# Out:
# actor_1_name
# 50 Cent           30981850.0
# A.J. Buckley     123070338.0
# Aaliyah           30307804.0
# Aasif Mandvi      13214030.0
# Abbie Cornish     25034383.0
# Name: gross, dtype: float64

# %%
m.groupby('actor_1_name')['budget'].mean().head(5)
# Out:
# actor_1_name
# 50 Cent          40000000.0
# A.J. Buckley            NaN
# Aaliyah          35000000.0
# Aasif Mandvi     20000000.0
# Abbie Cornish    34500000.0
# Name: budget, dtype: float64

# %%
m.groupby('actor_1_name')['gross'].mean().tail(5)
# Out:
# actor_1_name
# Zoë Kravitz              24723855.0
# Zuhair Haddad                   NaN
# Álex Angulo                     NaN
# Ólafur Darri Ólafsson           NaN
# Óscar Jaenada            54257433.0
# Name: gross, dtype: float64

# %%
m.groupby('actor_1_name')['budget'].mean().tail(5)
# Out:
# actor_1_name
# Zoë Kravitz              1.356667e+07
# Zuhair Haddad            1.300000e+06
# Álex Angulo                       NaN
# Ólafur Darri Ólafsson             NaN
# Óscar Jaenada            1.700000e+07
# Name: budget, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.title('Top 10 Countries With Highest Median Budget')
plt.xlabel('Budget(1e9) in dollars')
m.groupby('country')['budget'].mean().sort_values(ascending=False).head(10).plot.barh(alpha=.7)

# %%
m.groupby('country')['gross'].mean().head(5)
# Out:
# country
# Afghanistan    1.127331e+06
# Argentina      7.230936e+06
# Aruba          1.007614e+07
# Australia      3.779466e+07
# Bahamas                 NaN
# Name: gross, dtype: float64

# %%
m.groupby('country')['gross'].mean().tail(5)
# Out:
# country
# Turkey                           NaN
# UK                      3.049946e+07
# USA                     5.453055e+07
# United Arab Emirates             NaN
# West Germany            1.143313e+07
# Name: gross, dtype: float64

# %% [markdown]
# # highest duration of movies in different languages: top 10

# %%
plt.figure(figsize=(8,6))
plt.title("Duration of Movies in Different Languages: Top 10")
plt.xlabel('Duration in Minutes')
m.groupby('language')['duration'].mean().sort_values(ascending=False).head(10).plot.barh(alpha=.7)

# %%
m[m['actor_1_name'] == 'Keanu Reeves'].sort_values('budget',ascending=False).head(10)
# Out:
#                                color         director_name  \
# movie_title
# 47 Ronin                       Color           Carl Rinsch
# Something's Gotta Give         Color          Nancy Meyers
# The Day the Earth Stood Still  Color      Scott Derrickson
# The Matrix                     Color        Lana Wachowski
# The Devil's Advocate           Color       Taylor Hackford
# Chain Reaction                 Color          Andrew Davis
# The Replacements               Color         Howard Deutch
# Bram Stoker's Dracula          Color  Francis Ford Coppola
# The Lake House                 Color     Alejandro Agresti
# Sweet November                 Color          Pat O'Connor
#
#                                num_critic_for_reviews  duration  \
# movie_title
# 47 Ronin                                        218.0     128.0
# Something's Gotta Give                          145.0     128.0
# The Day the Earth Stood Still                   276.0     104.0
# ...

# %%
m[m['actor_1_name'] == 'Keanu Reeves'].sort_values('gross',ascending=False).head(10)
# Out:
#                                   color         director_name  \
# movie_title
# The Matrix                        Color        Lana Wachowski
# Something's Gotta Give            Color          Nancy Meyers
# Speed                             Color           Jan de Bont
# Bram Stoker's Dracula             Color  Francis Ford Coppola
# The Day the Earth Stood Still     Color      Scott Derrickson
# The Devil's Advocate              Color       Taylor Hackford
# The Lake House                    Color     Alejandro Agresti
# The Replacements                  Color         Howard Deutch
# Bill & Ted's Excellent Adventure  Color         Stephen Herek
# Hardball                          Color         Brian Robbins
#
#                                   num_critic_for_reviews  duration  \
# movie_title
# The Matrix                                         313.0     136.0
# Something's Gotta Give                             145.0     128.0
# ...
